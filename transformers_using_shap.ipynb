# %%
import shap
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, GlobalAveragePooling1D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

texts = ["I love using SHAP with transformers", "This is terrible", "Absolutely amazing"]
labels = [1, 0, 1]

tokenizer = Tokenizer(num_words=1000, oov_token="<OOV>")
tokenizer.fit_on_texts(texts)
X = pad_sequences(tokenizer.texts_to_sequences(texts), maxlen=10)
y = np.array(labels)


input_layer = Input(shape=(10,))
x = Embedding(input_dim=1000, output_dim=32)(input_layer)
x = GlobalAveragePooling1D()(x)
x = Dense(16, activation="relu")(x)
output = Dense(1, activation="sigmoid")(x)
model = Model(input_layer, output)
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
model.fit(X, y, epochs=5, batch_size=1)

def predict_fn(text_input):
    seq = tokenizer.texts_to_sequences(text_input)
    padded = pad_sequences(seq, maxlen=10)
    return model.predict(padded)

masker = shap.maskers.Text(" ")

explainer = shap.Explainer(predict_fn, masker)

shap_values = explainer(["I love using SHAP with transformers"])
shap.plots.text(shap_values[0])
# Out:
# Epoch 1/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5417 - loss: 0.6960
# Epoch 2/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5417 - loss: 0.6887
# Epoch 3/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.6869
# Epoch 4/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.6864
# Epoch 5/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4583 - loss: 0.6853
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# <div align='center'>
# <script>
#     document._hover_uzicpddqkixbqcivqjpc = '_tp_uzicpddqkixbqcivqjpc_output_0';
#     document._zoom_uzicpddqkixbqcivqjpc = undefined;
#     function _output_onclick_uzicpddqkixbqcivqjpc(i) {
#         var next_id = undefined;
#
#         if (document._zoom_uzicpddqkixbqcivqjpc !== undefined) {
#             document.getElementById(document._zoom_uzicpddqkixbqcivqjpc+ '_zoom').style.display = 'none';
#
#             if (document._zoom_uzicpddqkixbqcivqjpc === '_tp_uzicpddqkixbqcivqjpc_output_' + i) {
#                 document.getElementById(document._zoom_uzicpddqkixbqcivqjpc).style.display = 'block';
#                 document.getElementById(document._zoom_uzicpddqkixbqcivqjpc+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_uzicpddqkixbqcivqjpc).style.display = 'none';
#                 document.getElementById(document._zoom_uzicpddqkixbqcivqjpc+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_uzicpddqkixbqcivqjpc !== '_tp_uzicpddqkixbqcivqjpc_output_' + i) {
#             next_id = '_tp_uzicpddqkixbqcivqjpc_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_uzicpddqkixbqcivqjpc = next_id;
#     }
#     function _output_onmouseover_uzicpddqkixbqcivqjpc(i, el) {
#         if (document._zoom_uzicpddqkixbqcivqjpc !== undefined) { return; }
#         if (document._hover_uzicpddqkixbqcivqjpc !== undefined) {
#             document.getElementById(document._hover_uzicpddqkixbqcivqjpc + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_uzicpddqkixbqcivqjpc).style.display = 'none';
#         }
#         document.getElementById('_tp_uzicpddqkixbqcivqjpc_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_uzicpddqkixbqcivqjpc = '_tp_uzicpddqkixbqcivqjpc_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_uzicpddqkixbqcivqjpc_output_0_name"
#     onclick="_output_onclick_uzicpddqkixbqcivqjpc(0)"
#     onmouseover="_output_onmouseover_uzicpddqkixbqcivqjpc(0, this);">Output 0</div><br><br><div id='_tp_uzicpddqkixbqcivqjpc_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.59978037914291%" y1="33" x2="49.59978037914291%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.59978037914291%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.511</text><line x1="29.834060177465208%" y1="33" x2="29.834060177465208%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="29.834060177465208%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.51</text><line x1="10.068339975787502%" y1="33" x2="10.068339975787502%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="10.068339975787502%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.509</text><line x1="69.36550058082062%" y1="33" x2="69.36550058082062%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="69.36550058082062%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.512</text><line x1="89.13122078249833%" y1="33" x2="89.13122078249833%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="89.13122078249833%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.513</text><line x1="15.696326900658885%" y1="33" x2="15.696326900658885%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="15.696326900658885%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.509285</text><text x="15.696326900658885%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.509285</text><text x="15.696326900658885%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="84.3034754421391%" y1="33" x2="84.3034754421391%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="84.3034754421391%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.512756</text><text x="84.3034754421391%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.512756</text><text x="84.3034754421391%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">Output 0</tspan>(inputs)</text><rect x="8.333316861899466%" width="75.97015858023963%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="54.541587430756174%" x2="84.3034754421391%" y1="60" y2="60" id="_fb_scthwwrkphqfunylrdbv_ind_4" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="69.42253143644764%" y="71" font-size="12px" id="_fs_scthwwrkphqfunylrdbv_ind_4" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.002</text><svg x="54.541587430756174%" y="40" height="20" width="29.76188801138293%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">with</text>  </svg></svg><line x1="29.810309102241%" x2="54.541587430756174%" y1="60" y2="60" id="_fb_scthwwrkphqfunylrdbv_ind_5" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="42.17594826649859%" y="71" font-size="12px" id="_fs_scthwwrkphqfunylrdbv_ind_5" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anc ...
